# %%
import numpy as np
import pandas as pd
df=pd.read_csv("/content/Advertising.csv")
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.isna().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
x=df.iloc[:,:-1]
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64

# %%
import seaborn as sns
sns.regplot(x=df['TV'],y=y,color='red')

# %%
sns.regplot(x=df['Radio'],y=y,color='green')

# %%
sns.regplot(x=df['Newspaper'],y=y,color='blue')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)
x_train
# Out:
#         TV  Radio  Newspaper
# 169  284.3   10.6        6.4
# 97   184.9   21.0       22.0
# 31   112.9   17.4       38.6
# 12    23.8   35.1       65.9
# 35   290.7    4.1        8.5
# ..     ...    ...        ...
# 106   25.0   11.0       29.7
# 14   204.1   32.9       46.0
# 92   217.7   33.5       59.0
# 179  165.6   10.0       17.6
# 102  280.2   10.1       21.4
#
# [140 rows x 3 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([18. , 23.8, 19.8,  5.3, 23.8, 15.3, 22.6,  9.6, 17.8, 17.1,  8.8,
#         9.7, 16.7,  1.6, 12.6, 17.6,  4.8, 17. , 11.9, 20.9, 19.8, 15.3,
#        10.8, 21.5,  9.7,  9.7, 22.6, 13.2, 11.9,  4.8, 15.5, 13.2, 23.8,
#        12. , 20.1, 20.9, 10.4, 19.8, 13.2,  6.6, 12.6, 17.6, 10.1,  9.6,
#        17.5,  9.6, 12.3, 10.1, 13.2, 14. , 13.6, 17.6,  4.8,  4.8, 11.9,
#        13.2, 13.2, 25.5,  6.6, 15.5])

# %%
df1=pd.DataFrame({'Actual_Value':y_test,'Predicted_Value':y_pred})
df1
# Out:
#      Actual_Value  Predicted_Value
# 95           16.9             18.0
# 15           22.4             23.8
# 30           21.4             19.8
# 158           7.3              5.3
# 128          24.7             23.8
# 115          12.6             15.3
# 69           22.3             22.6
# 170           8.4              9.6
# 174          16.5             17.8
# 45           16.1             17.1
# 66           11.0              8.8
# 182           8.7              9.7
# 165          16.9             16.7
# 78            5.3              1.6
# 186          10.3             12.6
# 177          16.7             17.6
# 56            5.5              4.8
# 152          16.6             17.0
# 82           11.3             11.9
# 68           18.9             20.9
# 124          19.7             19.8
# 16           12.5             15.3
# 148          10.9             10.8
# 93           22.2             21.5
# 65           11.3              9.7
# 60            8.1              9.7
# 84           21.7             22.6
# 67           13.4             13.2
# 125          10.6             11.9
# 132           5.7              4.8
# 9            15.6             15.5
# 18           11.3             13.2
# 55           23.7             23.8
# 75            8.7             12.0
# 150          16.1             20.1
# 104          20.7             20.9
# 135          11.6             10.4
# 137          20.8             19.8
# 164          11.9             13.2
# 76            6.9              6.6
# 79           11.0             12.6
# 197          14.8             17.6
# 38           10.1             10.1
# 24            9.7              9.6
# 122          16.6             17.5
# 195           7.6              9.6
# 29           10.5             12.3
# 19           14.6             10.1
# 143          10.4             13.2
# 86           12.0             14.0
# 114          14.6             13.6
# 173          16.7             17.6
# 5             7.2              4.8
# 126           6.6              4.8
# 117           9.4             11.9
# 73           11.0             13.2
# 140          10.9             13.2
# 98           25.4             25.5
# 172           7.6              6.6
# 96           16.7             15.5

# %%
from sklearn.metrics import mean_absolute_error
print("Error is",mean_absolute_error(y_test,y_pred))
# Out:
# Error is 1.416666666666667

# %%
from sklearn.metrics import mean_absolute_percentage_error
print("Percentage error is",mean_absolute_percentage_error(y_test,y_pred))
# Out:
# Percentage error is 0.13155946437197683

# %%
from sklearn.metrics import mean_squared_error
z=mean_squared_error(y_test,y_pred)

# %%
import numpy as np
print(np.sqrt(z))
# Out:
# 1.7536628334241828

# %%
from sklearn.metrics import r2_score
print("R2 score",r2_score(y_test,y_test))
# Out:
# R2 score 1.0
